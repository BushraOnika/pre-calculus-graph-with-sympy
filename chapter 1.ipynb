# %%
from sympy import *

# %%
x , y= symbols("x y")

# %%
y=sqrt(x)

# %%
dy=y.subs(x,6)-y.subs(x,3)
dx=(6-3)
N(dy/dx)
# Out:
# 0.239146311738100

# %%
dy=y.subs(x,6)-y.subs(x,2)
dx=(6-2)
N(dy/dx)
# Out:
# 0.258819045102521

# %%
diff(y,x)
# Out:
# 1/(2*sqrt(x))

# %%
plot(y)

# %%
x , y= symbols("x y")
y=sqrt(5-x**2)
y
# Out:
# sqrt(5 - x**2)

# %%
plot(y)

# %%
y=2*x-6
y
plot(y)

# %%
y=x**2
plot(y)

# %%
y=4*(x**2)/(x**2+1)
plot(y)

# %%
r=symbols("r")

# %%
y=sqrt(r**2-x**2)
y
plot(y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 3
#       1 y=sqrt(r**2-x**2)
#       2 y
# ----> 3 plot(y)
#
# File D:\PythonProject\pre calculus graph with sympy\.venv\lib\site-packages\sympy\plotting\plot.py:398, in plot(show, *args, **kwargs)
#     209 """Plots a function of a single variable as a curve.
#     210
#     211 Parameters
#    (...)
#     395
#     396 """
#     397 args = _plot_sympify(args)
# --> 398 plot_expr = _check_arguments(args, 1, 1, **kwargs)
#     399 params = kwargs.get("params", None)
#     400 free = set()
#
# File D:\PythonProject\pre calculus graph with sympy\.venv\lib\site-packages\sympy\plotting\utils.py:266, in _check_arguments(args, nexpr, npar, **kwargs)
#     264 exprs, ranges, label, rendering_kw = _unpack_args(*args)
#     265 free_symbols = set().union(*[e.free_symbols for e in exprs])
# ...
